# %%
import pandas as pd
import sns
from matplotlib import pyplot

# %%
df = pd.read_csv('employee_churn_dataset.csv')

# %%
df.head(20)
# Out:
#    Employee ID  Age  Gender Education Level Marital Status  Tenure   Job Role  \
# 0       E00001   50    Male      Bachelor's        Married       5    Analyst
# 1       E00002   36    Male      Bachelor's        Married       4    Manager
# 2       E00003   29    Male      Bachelor's        Married       3      Sales
# 3       E00004   42    Male      Bachelor's         Single      12    Analyst
# 4       E00005   40   Other      Bachelor's        Married       1      Sales
# 5       E00006   44    Male      Bachelor's         Single      12  Developer
# 6       E00007   32    Male     High School        Married      12    Analyst
# 7       E00008   32    Male        Master's         Single       6    Manager
# 8       E00009   45  Female        Master's         Single       4    Analyst
# 9       E00010   57    Male     High School        Married      12  Developer
# 10      E00011   45  Female        Master's        Married       2  Developer
# 11      E00012   24  Female        Master's        Married       5      Sales
# 12      E00013   43    Male     High School       Divorced       7    Manager
# 13      E00014   23    Male      Bachelor's         Single      10    Manager
# 14      E00015   45    Male      Bachelor's        Married       9    Manager
# 15      E00016   51  Female      Bachelor's        Married       9    Analyst
# 16      E00017   59    Male        Master's        Married      11  Developer
# 17      E00018   23    Male      Bachelor's        Married       1    Manager
# 18      E00019   42    Male     High School        Married      10  Developer
# 19      E00020   54  Female             PhD        Married       9    Analyst
#
#    Department  Salary Work Location  ...  Training Hours  Promotions  \
# 0   Marketing   93422        Remote  ...              35           0
# 1       Sales   44589       On-site  ...               1           0
# 2          IT   56768        Hybrid  ...              41           0
# 3       Sales   79009       On-site  ...              33           0
# 4          HR   81982       On-site  ...              30           0
# 5          HR   82669       On-site  ...              68           0
# 6   Marketing  127951       On-site  ...              19           0
# 7       Sales   93655        Remote  ...              37           0
# 8       Sales   69050        Remote  ...              74           0
# 9   Marketing  106153        Hybrid  ...              94           0
# 10         IT   79420        Remote  ...              88           0
# 11         IT  104064       On-site  ...               3           0
# 12         HR  149835       On-site  ...              84           0
# 13      Sales   74784       On-site  ...              61           0
# 14      Sales  110337        Hybrid  ...               0           0
# 15      Sales   68043       On-site  ...              41           0
# 16         HR   45279       On-site  ...              50           0
# 17      Sales   41702       On-site  ...              36           0
# 18      Sales  135487       On-site  ...              42           0
# 19         IT   68691       On-site  ...              91           0
#
#     Overtime Hours  Satisfaction Level  Work-Life Balance  \
# 0               16                0.03               Poor
# 1               12                0.39            Average
# 2                2                0.62               Poor
# 3                8                0.73               Good
# 4               13                0.52            Average
# 5                2                0.06            Average
# 6               35                0.76            Average
# 7               19                0.39            Average
# 8               45                0.18          Excellent
# 9               17                0.26               Good
# 10               0                0.67            Average
# 11              19                0.20               Good
# 12              28                0.09            Average
# 13              23                0.62               Good
# 14              31                0.65            Average
# 15              18                0.45            Average
# 16               4                0.51            Average
# 17              24                0.83            Average
# 18              23                0.34            Average
# 19              39                0.86            Average
#
#     Average Monthly Hours Worked Absenteeism  Distance from Home  \
# 0                            155          14                  15
# 1                            162           2                   8
# 2                            243           6                  21
# 3                            291          11                  25
# 4                            272           3                   1
# 5                            266           4                  40
# 6                            233          10                  10
# 7                            204           1                  14
# 8                            162          15                  36
# 9                            151          19                  27
# 10                           275           6                  19
# 11                           156          17                   2
# 12                           171           5                   4
# 13                           205          13                  24
# 14                           253           0                  36
# 15                           229           1                   3
# 16                           274          13                  11
# 17                           298          15                  27
# 18                           200          11                   4
# 19                           195           6                  38
#
#     Manager Feedback Score  Churn
# 0                      7.9      0
# 1                      5.2      0
# 2                      6.3      0
# 3                      7.4      0
# 4                      4.1      0
# 5                      2.1      0
# 6                      4.9      0
# 7                      7.3      0
# 8                      4.9      1
# 9                      4.7      0
# 10                     6.8      0
# 11                     1.1      0
# 12                     7.0      0
# 13                     1.5      0
# 14                    10.0      0
# 15                     1.1      0
# 16                     6.0      0
# 17                     8.9      0
# 18                     8.1      0
# 19                     7.0      0
#
# [20 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Education Level', 'Marital Status',
#        'Tenure', 'Job Role', 'Department', 'Salary', 'Work Location',
#        'Performance Rating', 'Projects Completed', 'Training Hours',
#        'Promotions', 'Overtime Hours', 'Satisfaction Level',
#        'Work-Life Balance', 'Average Monthly Hours Worked', 'Absenteeism',
#        'Distance from Home', 'Manager Feedback Score', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Employee ID                     0
# Age                             0
# Gender                          0
# Education Level                 0
# Marital Status                  0
# Tenure                          0
# Job Role                        0
# Department                      0
# Salary                          0
# Work Location                   0
# Performance Rating              0
# Projects Completed              0
# Training Hours                  0
# Promotions                      0
# Overtime Hours                  0
# Satisfaction Level              0
# Work-Life Balance               0
# Average Monthly Hours Worked    0
# Absenteeism                     0
# Distance from Home              0
# Manager Feedback Score          0
# Churn                           0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Employee ID                     0
# Age                             0
# Gender                          0
# Education Level                 0
# Marital Status                  0
# Tenure                          0
# Job Role                        0
# Department                      0
# Salary                          0
# Work Location                   0
# Performance Rating              0
# Projects Completed              0
# Training Hours                  0
# Promotions                      0
# Overtime Hours                  0
# Satisfaction Level              0
# Work-Life Balance               0
# Average Monthly Hours Worked    0
# Absenteeism                     0
# Distance from Home              0
# Manager Feedback Score          0
# Churn                           0
# dtype: int64

# %%
from matplotlib import pyplot as plt
#display data in a pie chart

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Employee ID                   10000 non-null  object
#  1   Age                           10000 non-null  int64
#  2   Gender                        10000 non-null  object
#  3   Education Level               10000 non-null  object
#  4   Marital Status                10000 non-null  object
#  5   Tenure                        10000 non-null  int64
#  6   Job Role                      10000 non-null  object
#  7   Department                    10000 non-null  object
#  8   Salary                        10000 non-null  int64
#  9   Work Location                 10000 non-null  object
#  10  Performance Rating            10000 non-null  int64
#  11  Projects Completed            10000 non-null  int64
#  12  Training Hours                10000 non-null  int64
#  13  Promotions                    10000 non-null  int64
#  14  Overtime Hours                10000 non-null  int64
#  15  Satisfaction Level            10000 non-null  float64
#  16  Work-Life Balance             10000 non-null  object
#  17  Average Monthly Hours Worked  10000 non-null  int64
#  18  Absenteeism                   10000 non-null  int64
#  19  Distance from Home            10000 non-null  int64
#  20  Manager Feedback Score        10000 non-null  float64
#  21  Churn                         10000 non-null  int64
# dtypes: float64(2), int64(12), object(8)
# memory usage: 1.7+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['Department','Salary','Absenteeism', 'Promotions', 'Churn']

plt.figure(figsize=(12, 15))

for i, col in enumerate(features):
    plt.subplot(4, 2, i+1)
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=90)
    plt.title(f"Employee distribution by {col}")

plt.tight_layout()
plt.show()
